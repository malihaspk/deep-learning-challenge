# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.

application_df = application_df.drop( ['EIN'], axis=1)

# %%
application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.

application_df_unique = application_df.nunique().sort_values()
print(application_df_unique)
# Out:
# STATUS                        2
# SPECIAL_CONSIDERATIONS        2
# IS_SUCCESSFUL                 2
# ORGANIZATION                  4
# USE_CASE                      5
# AFFILIATION                   6
# INCOME_AMT                    9
# APPLICATION_TYPE             17
# CLASSIFICATION               71
# ASK_AMT                    8747
# NAME                      19568
# dtype: int64

# %%
# Look at NAME value counts for binning

application_df['NAME'].value_counts()
# Out:
# Other                                      21022
# PARENT BOOSTER USA INC                      1260
# TOPS CLUB INC                                765
# UNITED STATES BOWLING CONGRESS INC           700
# WASHINGTON STATE UNIVERSITY                  492
#                                            ...
# CASCADE 4-H FOUNDATION                        10
# FREE & ACCEPTED MASONS OF WASHINGTON          10
# NEW MEXICO GARDEN CLUBS INC                   10
# NATIONAL ASSOCIATION OF HISPANIC NURSES       10
# UNION OF CALIFORNIA STATE WORKERS             10
# Name: NAME, Length: 223, dtype: int64

# %%
# Choose a cutoff value
# create a list of NAME to be replace

NAME_replace_filter_series = application_df["NAME"].value_counts() < 10
NAME_replace_filter_series
# Out:
# Other                                      False
# PARENT BOOSTER USA INC                     False
# TOPS CLUB INC                              False
# UNITED STATES BOWLING CONGRESS INC         False
# WASHINGTON STATE UNIVERSITY                False
#                                            ...
# CASCADE 4-H FOUNDATION                     False
# FREE & ACCEPTED MASONS OF WASHINGTON       False
# NEW MEXICO GARDEN CLUBS INC                False
# NATIONAL ASSOCIATION OF HISPANIC NURSES    False
# UNION OF CALIFORNIA STATE WORKERS          False
# Name: NAME, Length: 223, dtype: bool

# %%
NAME_to_replace = application_df["NAME"].value_counts()[NAME_replace_filter_series].index

# %%
# Replace in dataframe
for app in NAME_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(app,"Other")

# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# Other                                      21022
# PARENT BOOSTER USA INC                      1260
# TOPS CLUB INC                                765
# UNITED STATES BOWLING CONGRESS INC           700
# WASHINGTON STATE UNIVERSITY                  492
#                                            ...
# CASCADE 4-H FOUNDATION                        10
# FREE & ACCEPTED MASONS OF WASHINGTON          10
# NEW MEXICO GARDEN CLUBS INC                   10
# NATIONAL ASSOCIATION OF HISPANIC NURSES       10
# UNION OF CALIFORNIA STATE WORKERS             10
# Name: NAME, Length: 223, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value
# create a list of application types to be replaced
APPLICATION_TYPE_CUTOFF = 500

application_type_replace_filter_series = application_df["APPLICATION_TYPE"].value_counts() < APPLICATION_TYPE_CUTOFF
application_type_replace_filter_series
# Out:
# T3     False
# T4     False
# T6     False
# T5     False
# T19    False
# T8     False
# T7     False
# T10    False
# T9      True
# T13     True
# T12     True
# T2      True
# T25     True
# T14     True
# T29     True
# T15     True
# T17     True
# Name: APPLICATION_TYPE, dtype: bool

# %%
# use the variable name `application_types_to_replace`
application_types_to_replace = application_df["APPLICATION_TYPE"].value_counts()[application_type_replace_filter_series].index

# %%
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_df.loc[25:50]
# Out:
#                                            NAME APPLICATION_TYPE  \
# 25                                        Other               T4
# 26      INFRAGARD NATIONAL MEMBERS ALLIANCE INC               T3
# 27               POP WARNER LITTLE SCHOLARS INC               T3
# 28  FLORIDA STATE UNIVERSITY ALUMNI ASSOCIATION               T3
# 29                                        Other               T6
# 30                                        Other               T6
# 31                                        Other               T3
# 32                                        Other               T7
# 33                                        Other               T3
# 34                                        Other               T3
# 35                                        Other               T3
# 36                                        Other               T4
# 37                                        Other               T3
# 38                                        Other               T7
# 39                                        Other               T3
# 40                                        Other               T3
# 41                                        Other            Other
# 42                                        Other               T7
# 43       HABITAT FOR HUMANITY INTERNATIONAL INC               T3
# 44                                        Other               T3
# 45                                        Other               T3
# 46                           PTA TEXAS CONGRESS               T3
# 47                                        Other               T7
# 48                                        Other               T3
# 49                                        Other               T3
# 50                                        Other               T3
#
#          AFFILIATION CLASSIFICATION      USE_CASE ORGANIZATION  STATUS  \
# 25       Independent          C3000    ProductDev        Trust       1
# 26  CompanySponsored          C1000  Preservation        Trust       1
# 27  CompanySponsored          C2000  Preservation        Trust       1
# 28  CompanySponsored          C2000  Preservation        Trust       1
# 29       Independent          C2000    ProductDev        Trust       1
# 30       Independent          C2000    ProductDev        Trust       1
# 31       Independent          C1200  Preservation        Trust       1
# 32       Independent          C1000    ProductDev        Trust       1
# 33  CompanySponsored          C1000  Preservation        Trust       1
# 34       Independent          C1000  Preservation        Trust       1
# 35       Independent          C1200  Preservation        Trust       1
# 36       Independent          C1000    ProductDev        Trust       1
# 37       Independent          C1000  Preservation        Trust       1
# 38       Independent          C1000    ProductDev  Association       1
# 39       Independent          C1000  Preservation        Trust       1
# 40       Independent          C1000  Preservation        Trust       1
# 41       Independent          C1000    ProductDev        Trust       1
# 42       Independent          C1000    ProductDev        Trust       1
# 43  CompanySponsored          C1000  Preservation        Trust       1
# 44       Independent          C7200  Preservation        Trust       1
# 45       Independent          C1000  Preservation        Trust       1
# 46  CompanySponsored          C2000  Preservation        Trust       1
# 47       Independent          C1000    ProductDev        Trust       1
# 48       Independent          C1700  Preservation        Trust       1
# 49       Independent          C1000  Preservation        Trust       1
# 50       Independent          C1000  Preservation        Trust       1
#
#        INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 25              0                      N     5000              1
# 26              0                      N     5000              1
# 27    25000-99999                      N    44004              1
# 28              0                      N     5000              0
# 29              0                      N     5000              1
# 30  100000-499999                      N   323466              1
# 31              0                      N     5000              1
# 32              0                      N     5000              1
# 33              0                      N     5000              1
# 34              0                      N     5000              0
# 35              0                      N     5000              0
# 36              0                      N     5000              1
# 37              0                      N     5000              1
# 38              0                      N     5000              0
# 39    25000-99999                      N     5000              1
# 40    25000-99999                      N   709815              0
# 41    25000-99999                      N  1329410              0
# 42              0                      N     5000              1
# 43              0                      N     5000              0
# 44              0                      N     5000              1
# 45              0                      N     5000              1
# 46              0                      N     5000              0
# 47              0                      N     5000              0
# 48              0                      N     5000              1
# 49              0                      N     5000              0
# 50  100000-499999                      N    31613              1

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_gt_1_filter_series = application_df['CLASSIFICATION'].value_counts()>1
application_df['CLASSIFICATION'].value_counts()[classification_gt_1_filter_series]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

CLASSIFICATION_TYPE_CUTOFF = 200

classification_replace_filter_series = application_df["CLASSIFICATION"].value_counts() < CLASSIFICATION_TYPE_CUTOFF
classification_replace_filter_series
classifications_to_replace= application_df["CLASSIFICATION"].value_counts()[classification_replace_filter_series].index


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1197
# C7000      777
# C1700      287
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_dummies = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df_dummies["IS_SUCCESSFUL"].values
# X = application_df_dummies.drop(["IS_SUCCESSFUL"],1).values
X = application_df_dummies.drop('IS_SUCCESSFUL', axis=1)

# %%
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 25


nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim= number_input_features))

# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
# Third hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               26900
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 25)                1275
#
#  dense_3 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 33251 (129.89 KB)
# Trainable params: 33251 (129.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled,y_train,epochs=30)
# Out:
# Epoch 1/30
# 804/804 [==============================] - 3s 2ms/step - loss: 0.4714 - accuracy: 0.7748
# Epoch 2/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4436 - accuracy: 0.7835
# Epoch 3/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4401 - accuracy: 0.7868
# Epoch 4/30
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4380 - accuracy: 0.7861
# Epoch 5/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4360 - accuracy: 0.7879
# Epoch 6/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4351 - accuracy: 0.7896
# Epoch 7/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4346 - accuracy: 0.7902
# Epoch 8/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4333 - accuracy: 0.7898
# Epoch 9/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4324 - accuracy: 0.7913
# Epoch 10/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4320 - accuracy: 0.7915
# Epoch 11/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4309 - accuracy: 0.7918
# Epoch 12/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4300 - accuracy: 0.7919
# Epoch 13/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4292 - accuracy: 0.7905
# Epoch 14/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4289 - accuracy: 0.7924
# Epoch 15/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4284 - accuracy: 0.7924
# Epoch 16/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4275 - accuracy: 0.7941
# Epoch 17/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4269 - accuracy: 0.7940
# Epoch 18/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4272 - accuracy: 0.7931
# Epoch 19/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4258 - accuracy: 0.7946
# Epoch 20/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4261 - accuracy: 0.7947
# Epoch 21/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4249 - accuracy: 0.7945
# Epoch 22/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4250 - accuracy: 0.7936
# Epoch 23/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4248 - accuracy: 0.7945
# Epoch 24/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4237 - accuracy: 0.7956
# Epoch 25/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4234 - accuracy: 0.7932
# Epoch 26/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4235 - accuracy: 0.7961
# Epoch 27/30
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4232 - accuracy: 0.7956
# Epoch 28/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4229 - accuracy: 0.7961
# Epoch 29/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4223 - accuracy: 0.7966
# Epoch 30/30
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4220 - accuracy: 0.7964

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.4581 - accuracy: 0.7838 - 665ms/epoch - 2ms/step
# Loss: 0.45812898874282837, Accuracy: 0.783790111541748

# %%
# Export our model to HDF5 file

#nn.save('AlphabetSoupCharity3.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# **Attemp Number 3 To Optimise the Model To Acheive Accuracy Higher than 75%**
#
# For Optimising the Model in this attempt 'Name' column is included and used binning for rare occurrences (for less than 10 value counts).
#
# Number of Hidden Layers = 3
#
# Number of Neurons for each Layer
#
# hidden_nodes_layer1 = 100
#
# hidden_nodes_layer2 = 50
#
# hidden_nodes_layer3 = 25
#
#  Result:
#
#  Making above changes to the model increased the accuracy to 78%.
